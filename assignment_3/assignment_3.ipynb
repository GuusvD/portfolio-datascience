# %%
import seaborn as sns

# %%
penguins = sns.load_dataset("penguins")

# %%
### A univariate analysis on all categorical data
penguins[['sex', 'species', 'island']].value_counts(dropna=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex,species,island'>
